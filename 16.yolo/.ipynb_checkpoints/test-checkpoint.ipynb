# %%
import torch

# %%
x = torch.rand(104, 6)
x
# Out:
# tensor([[0.1671, 0.6717, 0.4962, 0.9818, 0.3785, 0.1042],
#         [0.1561, 0.9888, 0.3632, 0.9395, 0.1284, 0.7977],
#         [0.5680, 0.6362, 0.1137, 0.2867, 0.1312, 0.8084],
#         [0.1033, 0.1864, 0.5178, 0.1607, 0.4865, 0.3206],
#         [0.3743, 0.2363, 0.6068, 0.5398, 0.6333, 0.7047],
#         [0.5967, 0.7079, 0.2161, 0.8710, 0.9443, 0.6179],
#         [0.2496, 0.6725, 0.4349, 0.3252, 0.0507, 0.2022],
#         [0.2987, 0.3649, 0.7684, 0.2294, 0.8855, 0.0980],
#         [0.6352, 0.3015, 0.6574, 0.1992, 0.0465, 0.3666],
#         [0.0918, 0.3423, 0.2230, 0.0449, 0.9788, 0.1234],
#         [0.0816, 0.3854, 0.3672, 0.2059, 0.1215, 0.8579],
#         [0.5474, 0.6255, 0.4302, 0.6416, 0.4481, 0.6462],
#         [0.1261, 0.1047, 0.8090, 0.8379, 0.4251, 0.5090],
#         [0.5280, 0.1806, 0.1240, 0.4936, 0.7720, 0.9804],
#         [0.2936, 0.9971, 0.3196, 0.4182, 0.9742, 0.2211],
#         [0.8357, 0.5753, 0.8686, 0.8135, 0.8242, 0.0135],
# ...

# %%
x.repeat(3, 1, 1).shape
# Out:
# torch.Size([3, 104, 6])
