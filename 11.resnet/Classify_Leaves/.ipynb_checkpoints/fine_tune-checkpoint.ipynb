# %%
import torch
from torch import nn
from torch.nn import functional as F
from d2l import torch as d2l

import os
from torchvision import transforms
from PIL import Image
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader, SubsetRandomSampler

# %%
img = Image.open("./images/0.jpg")
plt.imshow(img)

# %%
class LeavesImageDatasets(Dataset):
    def __init__(self, img_labels, transform = None):
        # super().__init__() # TODO:是否必须？
        self.transform = transform

        self.labels_df = pd.read_csv(img_labels)
        if self.labels_df.shape[1] > 1:
            self.is_train = True

            label_mapping = {}
            for i, label in enumerate(self.labels_df["label"].unique()):
                label_mapping[label] = i
            
            self.labels_df["label"] = self.labels_df["label"].map(label_mapping)
            self.labels = torch.tensor(self.labels_df["label"])
        else:
            self.is_train = False
            
    def __len__(self):
        return self.labels_df.shape[0]
        
    def __getitem__(self, index):
        image = Image.open(self.labels_df.iloc[index, 0])
        if self.transform:
            image = self.transform(image)

        if self.is_train:
            return image, self.labels[index]
        else:
            return image

# %%
batch_size = 256

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

leavesImageTrainDatasets = LeavesImageDatasets(img_labels="./train.csv", transform=transform)
num_samples = len(leavesImageTrainDatasets)
valid_size = int(0.2 * num_samples)  # 20% 的数据用作验证集

# 创建训练集和验证集的索引
indices = list(range(num_samples))
np.random.shuffle(indices)
valid_indices = indices[:valid_size]
train_indices = indices[valid_size:]

train_sampler = SubsetRandomSampler(train_indices)
valid_sampler = SubsetRandomSampler(valid_indices)
train_iter = DataLoader(leavesImageTrainDatasets, batch_size=batch_size, num_workers=4, sampler=train_sampler)
valid_iter = DataLoader(leavesImageTrainDatasets, batch_size=batch_size, num_workers=4, sampler=valid_sampler)

leavesImageTestDatasets = LeavesImageDatasets(img_labels="./test.csv", transform=transform)
test_iter = DataLoader(leavesImageTestDatasets, batch_size=256, shuffle=False, num_workers=4)
len(leavesImageTrainDatasets)
# Out:
# 18353

# %%
X_example, y_example = next(iter(train_iter))
print(X_example.shape, y_example.shape)
X_example, y_example = next(iter(valid_iter))
print(X_example.shape, y_example.shape)
test_example = next(iter(test_iter))
print(test_example.shape)
# Out:
# torch.Size([256, 3, 224, 224]) torch.Size([256])
# torch.Size([256, 3, 224, 224]) torch.Size([256])
# torch.Size([256, 3, 224, 224])

# %%
X_example[0]
# Out:
# tensor([[[-0.2684, -0.2684, -0.1828,  ...,  0.6563,  0.6049,  0.6221],
#          [-0.2513, -0.2171, -0.1657,  ...,  0.6049,  0.6563,  0.6049],
#          [-0.2513, -0.1657, -0.1314,  ...,  0.5878,  0.6906,  0.6221],
#          ...,
#          [ 0.0741,  0.0741,  0.0741,  ...,  0.0741,  0.0741,  0.0741],
#          [ 0.0741,  0.0741,  0.0741,  ...,  0.0741,  0.0741,  0.0741],
#          [ 0.0741,  0.0741,  0.0741,  ...,  0.0741,  0.0741,  0.0741]],
#
#         [[ 0.0826,  0.0476,  0.1352,  ...,  1.0105,  0.9580,  0.9755],
#          [ 0.1001,  0.1001,  0.1527,  ...,  0.9580,  0.9580,  0.9055],
#          [ 0.1001,  0.1527,  0.1877,  ...,  0.8880,  0.9930,  0.9230],
#          ...,
#          [ 0.2052,  0.2052,  0.2052,  ...,  0.2052,  0.2052,  0.2052],
#          [ 0.2052,  0.2052,  0.2052,  ...,  0.2052,  0.2052,  0.2052],
#          [ 0.2052,  0.2052,  0.2052,  ...,  0.2052,  0.2052,  0.2052]],
#
#         [[ 0.4091,  0.3742,  0.4614,  ...,  1.5071,  1.4548,  1.4722],
#          [ 0.4265,  0.4265,  0.4788,  ...,  1.4548,  1.4722,  1.4200],
#          [ 0.4265,  0.4788,  0.5136,  ...,  1.4025,  1.5071,  1.4374],
#          ...,
#          [ 0.4265,  0.4265,  0.4265,  ...,  0.4265,  0.4265,  0.4265],
#          [ 0.4265,  0.4265,  0.4265,  ...,  0.4265,  0.4265,  0.4265],
#          [ 0.4265,  0.4265,  0.4265,  ...,  0.4265,  0.4265,  0.4265]]])

# %%
class Residual(nn.Module):
    def __init__(self, in_channels, out_channels, use_1x1conv=False, stride=1):
        super().__init__()
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3,
                               padding=1, stride=stride)
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3,
                               padding=1)
        if use_1x1conv:
            self.conv3 = nn.Conv2d(in_channels, out_channels, kernel_size=1,
                                   stride=stride)
        else:
            self.conv3 = None

        self.bn1 = nn.BatchNorm2d(out_channels)
        self.bn2 = nn.BatchNorm2d(out_channels)

    def forward(self, X):
        Y = F.relu(self.bn1(self.conv1(X)))
        Y = self.bn2(self.conv2(Y))

        if self.conv3 is not None:
            X = self.conv3(X)
        Y += X
        return Y

b1 = nn.Sequential(nn.Conv2d(3, 64, kernel_size=7, stride=2, padding=3),
                   nn.BatchNorm2d(64), nn.ReLU(),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))

def resnet_block(input_channels, num_channels, num_residuals,
                 first_block=False):
    blk = []
    for i in range(num_residuals):
        if i == 0 and not first_block:
            blk.append(Residual(input_channels, num_channels,
                                use_1x1conv=True, stride=2))
        else:
            blk.append(Residual(num_channels, num_channels))
    return blk

b2 = nn.Sequential(*resnet_block(64, 64, 2, first_block=True))
b3 = nn.Sequential(*resnet_block(64, 128, 2))
b4 = nn.Sequential(*resnet_block(128, 256, 2))
b5 = nn.Sequential(*resnet_block(256, 512, 2))

net = nn.Sequential(b1, b2, b3, b4, b5,
                    nn.AdaptiveAvgPool2d((1,1)),
                    nn.Flatten(), nn.Linear(512, 176))

# %%
X = torch.rand((1, 3, 224, 224))
for module in net:
    X = module(X)
    print(module.__class__.__name__, X.shape)

total_params = 0
for name, param in net.named_parameters():
    print(f"Layer: {name} | Size: {param.size()} | Count: {param.nelement()} | {param.data.dtype}")
    total_params += param.nelement()

print(f"Total parameters count: {total_params}")
# Out:
# Sequential torch.Size([1, 64, 56, 56])
# Sequential torch.Size([1, 64, 56, 56])
# Sequential torch.Size([1, 128, 28, 28])
# Sequential torch.Size([1, 256, 14, 14])
# Sequential torch.Size([1, 512, 7, 7])
# AdaptiveAvgPool2d torch.Size([1, 512, 1, 1])
# Flatten torch.Size([1, 512])
# Linear torch.Size([1, 176])
# Layer: 0.0.weight | Size: torch.Size([64, 3, 7, 7]) | Count: 9408 | torch.float32
# Layer: 0.0.bias | Size: torch.Size([64]) | Count: 64 | torch.float32
# Layer: 0.1.weight | Size: torch.Size([64]) | Count: 64 | torch.float32
# Layer: 0.1.bias | Size: torch.Size([64]) | Count: 64 | torch.float32
# Layer: 1.0.conv1.weight | Size: torch.Size([64, 64, 3, 3]) | Count: 36864 | torch.float32
# Layer: 1.0.conv1.bias | Size: torch.Size([64]) | Count: 64 | torch.float32
# Layer: 1.0.conv2.weight | Size: torch.Size([64, 64, 3, 3]) | Count: 36864 | torch.float32
# Layer: 1.0.conv2.bias | Size: torch.Size([64]) | Count: 64 | torch.float32
# Layer: 1.0.bn1.weight | Size: torch.Size([64]) | Count: 64 | torch.float32
# Layer: 1.0.bn1.bias | Size: torch.Size([64]) | Count: 64 | torch.float32
# Layer: 1.0.bn2.weight | Size: torch.Size([64]) | Count: 64 | torch.float32
# Layer: 1.0.bn2.bias | Size: torch.Size([64]) | Count: 64 | torch.float32
# Layer: 1.1.conv1.weight | Size: torch.Size([64, 64, 3, 3]) | Count: 36864 | torch.float32
# Layer: 1.1.conv1.bias | Size: torch.Size([64]) | Count: 64 | torch.float32
# Layer: 1.1.conv2.weight | Size: torch.Size([64, 64, 3, 3]) | Count: 36864 | torch.float32
# Layer: 1.1.conv2.bias | Size: torch.Size([64]) | Count: 64 | torch.float32
# Layer: 1.1.bn1.weight | Size: torch.Size([64]) | Count: 64 | torch.float32
# Layer: 1.1.bn1.bias | Size: torch.Size([64]) | Count: 64 | torch.float32
# Layer: 1.1.bn2.weight | Size: torch.Size([64]) | Count: 64 | torch.float32
# Layer: 1.1.bn2.bias | Size: torch.Size([64]) | Count: 64 | torch.float32
# Layer: 2.0.conv1.weight | Size: torch.Size([128, 64, 3, 3]) | Count: 73728 | torch.float32
# Layer: 2.0.conv1.bias | Size: torch.Size([128]) | Count: 128 | torch.float32
# Layer: 2.0.conv2.weight | Size: torch.Size([128, 128, 3, 3]) | Count: 147456 | torch.float32
# Layer: 2.0.conv2.bias | Size: torch.Size([128]) | Count: 128 | torch.float32
# Layer: 2.0.conv3.weight | Size: torch.Size([128, 64, 1, 1]) | Count: 8192 | torch.float32
# Layer: 2.0.conv3.bias | Size: torch.Size([128]) | Count: 128 | torch.float32
# Layer: 2.0.bn1.weight | Size: torch.Size([128]) | Count: 128 | torch.float32
# Layer: 2.0.bn1.bias | Size: torch.Size([128]) | Count: 128 | torch.float32
# Layer: 2.0.bn2.weight | Size: torch.Size([128]) | Count: 128 | torch.float32
# Layer: 2.0.bn2.bias | Size: torch.Size([128]) | Count: 128 | torch.float32
# Layer: 2.1.conv1.weight | Size: torch.Size([128, 128, 3, 3]) | Count: 147456 | torch.float32
# Layer: 2.1.conv1.bias | Size: torch.Size([128]) | Count: 128 | torch.float32
# Layer: 2.1.conv2.weight | Size: torch.Size([128, 128, 3, 3]) | Count: 147456 | torch.float32
# Layer: 2.1.conv2.bias | Size: torch.Size([128]) | Count: 128 | torch.float32
# Layer: 2.1.bn1.weight | Size: torch.Size([128]) | Count: 128 | torch.float32
# Layer: 2.1.bn1.bias | Size: torch.Size([128]) | Count: 128 | torch.float32
# Layer: 2.1.bn2.weight | Size: torch.Size([128]) | Count: 128 | torch.float32
# Layer: 2.1.bn2.bias | Size: torch.Size([128]) | Count: 128 | torch.float32
# Layer: 3.0.conv1.weight | Size: torch.Size([256, 128, 3, 3]) | Count: 294912 | torch.float32
# Layer: 3.0.conv1.bias | Size: torch.Size([256]) | Count: 256 | torch.float32
# Layer: 3.0.conv2.weight | Size: torch.Size([256, 256, 3, 3]) | Count: 589824 | torch.float32
# Layer: 3.0.conv2.bias | Size: torch.Size([256]) | Count: 256 | torch.float32
# Layer: 3.0.conv3.weight | Size: torch.Size([256, 128, 1, 1]) | Count: 32768 | torch.float32
# Layer: 3.0.conv3.bias | Size: torch.Size([256]) | Count: 256 | torch.float32
# Layer: 3.0.bn1.weight | Size: torch.Size([256]) | Count: 256 | torch.float32
# Layer: 3.0.bn1.bias | Size: torch.Size([256]) | Count: 256 | torch.float32
# Layer: 3.0.bn2.weight | Size: torch.Size([256]) | Count: 256 | torch.float32
# Layer: 3.0.bn2.bias | Size: torch.Size([256]) | Count: 256 | torch.float32
# Layer: 3.1.conv1.weight | Size: torch.Size([256, 256, 3, 3]) | Count: 589824 | torch.float32
# Layer: 3.1.conv1.bias | Size: torch.Size([256]) | Count: 256 | torch.float32
# Layer: 3.1.conv2.weight | Size: torch.Size([256, 256, 3, 3]) | Count: 589824 | torch.float32
# Layer: 3.1.conv2.bias | Size: torch.Size([256]) | Count: 256 | torch.float32
# Layer: 3.1.bn1.weight | Size: torch.Size([256]) | Count: 256 | torch.float32
# Layer: 3.1.bn1.bias | Size: torch.Size([256]) | Count: 256 | torch.float32
# Layer: 3.1.bn2.weight | Size: torch.Size([256]) | Count: 256 | torch.float32
# Layer: 3.1.bn2.bias | Size: torch.Size([256]) | Count: 256 | torch.float32
# Layer: 4.0.conv1.weight | Size: torch.Size([512, 256, 3, 3]) | Count: 1179648 | torch.float32
# Layer: 4.0.conv1.bias | Size: torch.Size([512]) | Count: 512 | torch.float32
# Layer: 4.0.conv2.weight | Size: torch.Size([512, 512, 3, 3]) | Count: 2359296 | torch.float32
# Layer: 4.0.conv2.bias | Size: torch.Size([512]) | Count: 512 | torch.float32
# Layer: 4.0.conv3.weight | Size: torch.Size([512, 256, 1, 1]) | Count: 131072 | torch.float32
# Layer: 4.0.conv3.bias | Size: torch.Size([512]) | Count: 512 | torch.float32
# Layer: 4.0.bn1.weight | Size: torch.Size([512]) | Count: 512 | torch.float32
# Layer: 4.0.bn1.bias | Size: torch.Size([512]) | Count: 512 | torch.float32
# Layer: 4.0.bn2.weight | Size: torch.Size([512]) | Count: 512 | torch.float32
# Layer: 4.0.bn2.bias | Size: torch.Size([512]) | Count: 512 | torch.float32
# Layer: 4.1.conv1.weight | Size: torch.Size([512, 512, 3, 3]) | Count: 2359296 | torch.float32
# Layer: 4.1.conv1.bias | Size: torch.Size([512]) | Count: 512 | torch.float32
# Layer: 4.1.conv2.weight | Size: torch.Size([512, 512, 3, 3]) | Count: 2359296 | torch.float32
# Layer: 4.1.conv2.bias | Size: torch.Size([512]) | Count: 512 | torch.float32
# Layer: 4.1.bn1.weight | Size: torch.Size([512]) | Count: 512 | torch.float32
# Layer: 4.1.bn1.bias | Size: torch.Size([512]) | Count: 512 | torch.float32
# Layer: 4.1.bn2.weight | Size: torch.Size([512]) | Count: 512 | torch.float32
# Layer: 4.1.bn2.bias | Size: torch.Size([512]) | Count: 512 | torch.float32
# Layer: 7.weight | Size: torch.Size([176, 512]) | Count: 90112 | torch.float32
# Layer: 7.bias | Size: torch.Size([176]) | Count: 176 | torch.float32
# Total parameters count: 11269808

# %%
def train_ch6(net, train_iter, test_iter, num_epochs, lr, device):
    """Train a model with a GPU (defined in Chapter 6).

    Defined in :numref:`sec_lenet`"""
    def init_weights(m):
        if type(m) == nn.Linear or type(m) == nn.Conv2d:
            nn.init.xavier_uniform_(m.weight)
    net.apply(init_weights)
    print('training on', device)
    net.to(device)
    optimizer = torch.optim.Adam(net.parameters(), lr=lr)
    loss = nn.CrossEntropyLoss()
    # animator = d2l.Animator(xlabel='epoch', xlim=[1, num_epochs],
    #                         legend=['train loss', 'train acc', 'test acc'])
    timer, num_batches = d2l.Timer(), len(train_iter)
    for epoch in range(num_epochs):
        # Sum of training loss, sum of training accuracy, no. of examples
        metric = d2l.Accumulator(3)
        net.train()
        for i, (X, y) in enumerate(train_iter):
            timer.start()
            optimizer.zero_grad()
            X, y = X.to(device), y.to(device)
            y_hat = net(X)
            l = loss(y_hat, y)
            l.backward()
            optimizer.step()
            with torch.no_grad():
                metric.add(l * X.shape[0], d2l.accuracy(y_hat, y), X.shape[0])
            timer.stop()
            train_l = metric[0] / metric[2]
            train_acc = metric[1] / metric[2]
            # if (i + 1) % (num_batches // 5) == 0 or i == num_batches - 1:
            #     animator.add(epoch + (i + 1) / num_batches,
            #                  (train_l, train_acc, None))
        test_acc = d2l.evaluate_accuracy_gpu(net, test_iter)
        # animator.add(epoch + 1, (None, None, test_acc))
        print(f'epoch:{epoch} loss {train_l:.3f}, train acc {train_acc:.3f}, test acc {test_acc:.3f}')
    print(f'{metric[2] * num_epochs / timer.sum():.1f} examples/sec '
          f'on {str(device)}')

# %%
num_epochs, lr = 50, 1e-3

train_ch6(net, train_iter, valid_iter, num_epochs, lr, d2l.try_gpu())
# Out:
# training on cuda:0
# epoch:0 loss 4.632, train acc 0.078, test acc 0.090
# epoch:1 loss 3.172, train acc 0.228, test acc 0.147
# epoch:2 loss 2.528, train acc 0.341, test acc 0.213
# epoch:3 loss 2.105, train acc 0.426, test acc 0.128
# epoch:4 loss 1.729, train acc 0.516, test acc 0.099
# epoch:5 loss 1.426, train acc 0.588, test acc 0.224
# epoch:6 loss 1.234, train acc 0.637, test acc 0.117
# epoch:7 loss 1.055, train acc 0.685, test acc 0.284
# epoch:8 loss 0.870, train acc 0.736, test acc 0.538
# epoch:9 loss 0.768, train acc 0.762, test acc 0.488
# epoch:10 loss 0.677, train acc 0.789, test acc 0.625
# epoch:11 loss 0.600, train acc 0.812, test acc 0.640
# epoch:12 loss 0.544, train acc 0.831, test acc 0.513
# epoch:13 loss 0.465, train acc 0.851, test acc 0.525
# epoch:14 loss 0.368, train acc 0.884, test acc 0.449
# epoch:15 loss 0.357, train acc 0.886, test acc 0.660
# epoch:16 loss 0.318, train acc 0.900, test acc 0.686
# epoch:17 loss 0.294, train acc 0.905, test acc 0.695
# epoch:18 loss 0.264, train acc 0.915, test acc 0.659
# epoch:19 loss 0.233, train acc 0.925, test acc 0.704
# epoch:20 loss 0.220, train acc 0.929, test acc 0.572
# epoch:21 loss 0.196, train acc 0.938, test acc 0.695
# epoch:22 loss 0.150, train acc 0.951, test acc 0.750
# epoch:23 loss 0.148, train acc 0.955, test acc 0.725
# epoch:24 loss 0.132, train acc 0.958, test acc 0.771
# epoch:25 loss 0.114, train acc 0.963, test acc 0.800
# epoch:26 loss 0.105, train acc 0.969, test acc 0.740
# epoch:27 loss 0.108, train acc 0.967, test acc 0.764
# epoch:28 loss 0.118, train acc 0.962, test acc 0.713
# epoch:29 loss 0.113, train acc 0.965, test acc 0.733
# epoch:30 loss 0.114, train acc 0.962, test acc 0.753
# epoch:31 loss 0.095, train acc 0.970, test acc 0.766
# epoch:32 loss 0.126, train acc 0.959, test acc 0.371
# epoch:33 loss 0.127, train acc 0.957, test acc 0.685
# epoch:34 loss 0.096, train acc 0.969, test acc 0.608
# epoch:35 loss 0.066, train acc 0.980, test acc 0.795
# epoch:36 loss 0.057, train acc 0.982, test acc 0.702
# epoch:37 loss 0.052, train acc 0.983, test acc 0.790
# epoch:38 loss 0.059, train acc 0.980, test acc 0.801
# epoch:39 loss 0.050, train acc 0.982, test acc 0.668
# epoch:40 loss 0.048, train acc 0.983, test acc 0.714
# epoch:41 loss 0.076, train acc 0.975, test acc 0.756
# epoch:42 loss 0.110, train acc 0.963, test acc 0.340
# epoch:43 loss 0.128, train acc 0.957, test acc 0.531
# epoch:44 loss 0.125, train acc 0.958, test acc 0.330
# epoch:45 loss 0.142, train acc 0.952, test acc 0.634
# epoch:46 loss 0.110, train acc 0.963, test acc 0.795
# epoch:47 loss 0.084, train acc 0.972, test acc 0.257
# epoch:48 loss 0.075, train acc 0.975, test acc 0.675
# epoch:49 loss 0.057, train acc 0.981, test acc 0.780
# 1293.4 examples/sec on cuda:0

# %%
len(leavesImageTestDatasets)
# Out:
# 8800

# %%
labels_df = pd.read_csv("train.csv")
text_labels = []
for label in labels_df["label"].unique():
    text_labels.append(label)

def get_leaves_labels(labels):
    return [text_labels[int(i)] for i in labels]

# %%
def predict(net, leavesImageTestDatasets, device="cuda"):
    net.eval()
    preds =[]
    for X in leavesImageTestDatasets:
        X = X.to(device)
        X = X.reshape((1, ) + X.shape)
        net = net.to(device)
        preds.append(get_leaves_labels(d2l.argmax(net(X).to("cpu"), axis=1)))

    idx_df = pd.read_csv("test.csv")
    preds = pd.DataFrame(preds, columns=["label"])
    preds = pd.concat((idx_df, preds), axis=1)
    
    preds.to_csv('submission.csv', index=False)

# %%
predict(net, leavesImageTestDatasets, device="cuda")
